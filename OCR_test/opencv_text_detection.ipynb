# %%
import sys
import numpy as np 
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # gray 이미지로바꾸고  blur 먹이고 Threshhlod로 이진화

# %%
#img = cv2.imread('./image/crop_table2.PNG')
#img = cv2.imread(r'C:\OCR-SizeTable\OCR_test\crawling\tmp\screen_shot_0_9.jpg')
img = cv2.imread('./tttest2.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (5,5), 0)
thresh = cv2.adaptiveThreshold(blur, 255, 1, 1, 11, 2)

# %%
gray.shape
# Out:
# (212, 568)

# %%
plt.imshow(gray)

# %%
plt.imshow(blur)

# %%
plt.imshow(thresh)

# %% [markdown]
# # 윤곽 추출하기
# - 참조 : https://datascienceschool.net/view-notebook/f9f8983941254a34bf0fee42c66c5539/

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
# contours : 컨투어 포인트들의 배열이 리스트로 되어있음

# %%
print(f'contours len : {len(contours)}')
hierarchy
# Out:
# contours len : 83
# array([[[-1, -1,  1, -1],
#         [-1, -1,  2,  0],
#         [ 3, -1, -1,  1],
#         [ 4,  2, -1,  1],
#         [ 5,  3, -1,  1],
#         [ 6,  4, -1,  1],
#         [ 8,  5,  7,  1],
#         [-1, -1, -1,  6],
#         [ 9,  6, -1,  1],
#         [12,  8, 10,  1],
#         [11, -1, -1,  9],
#         [-1, 10, -1,  9],
#         [15,  9, 13,  1],
#         [14, -1, -1, 12],
#         [-1, 13, -1, 12],
#         [16, 12, -1,  1],
#         [18, 15, 17,  1],
#         [-1, -1, -1, 16],
#         [19, 16, -1,  1],
#         [20, 18, -1,  1],
#         [21, 19, -1,  1],
#         [22, 20, -1,  1],
#         [23, 21, -1,  1],
#         [24, 22, -1,  1],
#         [25, 23, -1,  1],
#         [26, 24, -1,  1],
#         [28, 25, 27,  1],
#         [-1, -1, -1, 26],
#         [30, 26, 29,  1],
#         [-1, -1, -1, 28],
#         [33, 28, 31,  1],
#         [32, -1, -1, 30],
#         [-1, 31, -1, 30],
#         [35, 30, 34,  1],
#         [-1, -1, -1, 33],
# ...

# %%
contours[0].shape
# Out:
# (1535, 1, 2)

# %%
for cnt in contours:
    x,y,w,h = cv2.boundingRect(cnt)
    if h > 50:
        continue
    red = (0, 0, 255)
    cv2.rectangle(img, (x,y), (x+w, y+h), red, 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

# %%
cv2.imwrite('check_test.png', img)
# Out:
# True
