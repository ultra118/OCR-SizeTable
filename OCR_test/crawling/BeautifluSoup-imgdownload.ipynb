# %%
from bs4 import BeautifulSoup
import urllib.request

shop_url = 'http://www.tmon.co.kr/deal/1959358378?NaPm=ct%3Djwk3obtc%7Cci%3D265e98e52a8d47dd798cb5e73c5c831654b8f5f6%7Ctr%3Dslsl%7Csn%3D221844%7Chk%3D4c2172339f11fa4d15e6b65e6108253d62b67cdf&utm_source=naver&utm_medium=affiliate&utm_term=&utm_content=&utm_campaign=%EB%84%A4%EC%9D%B4%EB%B2%84%EC%A7%80%EC%8B%9D%EC%87%BC%ED%95%91_%ED%86%B5%ED%95%A9%EA%B2%80%EC%83%89%ED%95%AB%EB%94%9C'

html = urllib.request.urlopen(shop_url)
source = html.read()

soup = BeautifulSoup(source, 'html.parser')

imgs = soup.find_all('img')
src_list = []
for img_ in imgs:
    src_list.append(img_.get('src'))

# %%
source
# Out:
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\n\n\n\t\n\n\n\n\n\t\n\t\n\t\t\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\n\t\n\n\n\n\n\n\n\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta charset="utf-8">\n<meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate">\n<meta http-equiv="Pragma" content="no-cache">\n<meta http-equiv="Expires" content="0">\n\n\n\t\n\t\n\t\t<meta name="google-site-verification" content="QdQofYukhicF9dhcY_spJY1lIoc9kWxs0FMB9y2UUMg">\n\t\n\n<meta name="google-site-verification" content="otX7rmNCEHEvuEEVe3ITip0T3ZWnsUufTJkTMscWDoU" />\n\n<meta name="viewport" content="width=1400">\n\n\n\n\t\n\t\n\t\n\t\t<title>\xed\x8b\xb0\xeb\xaa\xac - \xeb\xa7\xa4\xec\xa3\xbc \xec\x9b\x94\xec\x9a\x94\xec\x9d\xbc\xec\x9d\x80 \xed\x8b\x
# ...

# %%
imgs[7]
# Out:
# <img alt="티몬균일가" src="http://img4.tmon.kr/cdn3/resources/sticker/14_7b28e.png"/>
